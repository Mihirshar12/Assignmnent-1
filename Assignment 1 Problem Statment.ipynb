# %% [markdown]
# Download the dataset from the following link:
#
# https://drive.google.com/open?id=0B4c_CWtMboiGQk1VVmpNcElscU9NazZfTU1kdm5OTFdIX2ZB
#
# When you download the data and view it in microsoft excel, then it will look something like this:
#
# ![image.png](attachment:image.png)
#
# Notice that there are different columns inside this data, namely:
#
# Name of the Company
#
# Regional Office
#
# Address 1
#
# Address 2
#
# Address 3 and so on
#
# But, when you read the data after importing the pandas library and reading the excel file of the data using pd.read_excel( ) function:

# %%
import pandas as pd

# %%
data = pd.read_excel("./59260.xlsx")

# %% [markdown]
# We get the following output:

# %%
data.head()
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   List of NBFCs holding CoR for accepting Public Deposits (As on October 31, 2019) (Of this, only those NBFCs which are having requisite investment grade rating are authorized to accept fresh public deposits)  \
# 0                                               S No
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#                           Unnamed: 2       Unnamed: 3  \
# 0                Name of the company  Regional Office
# 1   ARMAN FINANCIAL SERVICES LIMITED        Ahmedabad
# 2               Chinmay Finlease Ltd        Ahmedabad
# 3             Ishan Finlease Limited        Ahmedabad
# 4  JAYLAKSHMI CREDIT COMPANY LIMITED        Ahmedabad
#
#                    Unnamed: 4              Unnamed: 5  \
# ...

# %% [markdown]
# Notice that the data which is read as a Pandas DataFrame has wrong column names and instead of that the correct column names are a part of DataFrame and you can see them 0th row of the DataFrame by executing:

# %%
data.iloc[0]
# Out:
# Unnamed: 0                                                                                                                                                                                                                        NaN
# List of NBFCs holding CoR for accepting Public Deposits (As on October 31, 2019) (Of this, only those NBFCs which are having requisite investment grade rating are authorized to accept fresh public deposits)                   S No
# Unnamed: 2                                                                                                                                                                                                        Name of the company
# Unnamed: 3                                                                                                                                                                                                            Regional Office
# ...

# %% [markdown]
# So, we should get the correct column names of our DataFrame as:
#
# S.No
#
# Name of the Company
#
# Address 1
#
# Address 2
#
# Address 3 and so on but instead of that, we are getting the following column names:

# %%
data.columns
# Out:
# Index(['Unnamed: 0',
#        'List of NBFCs holding CoR for accepting Public Deposits (As on October 31, 2019) (Of this, only those NBFCs which are having requisite investment grade rating are authorized to accept fresh public deposits)',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# Moreover, one extra column has entered in the output DataFrame and thats the first column going from left to right and that is:

# %%
data.columns[0]
# Out:
# 'Unnamed: 0'

# %% [markdown]
# This above mentioned column has all the values as 'NaN's and this can be seen:

# %%
data[data.columns[0]]
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
#       ..
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# 74   NaN
# 75   NaN
# 76   NaN
# 77   NaN
# 78   NaN
# 79   NaN
# 80   NaN
# 81   NaN
# Name: Unnamed: 0, Length: 82, dtype: float64

# %% [markdown]
# So, the first task of this assignment is to put the correct column names on the columns of this DataFrame and to remove the first column named 'Unnamed :0'

# %% [markdown]
# Now, coming to the second task of this assignment. You have to plot the frequency distributions of the 'City' column and 'State' column. This means that you have to plot bar plots for the both the columns where on X-axis, you can see the different names of the cities and different states and their count on the Y-axis and the bar plots will look something like that:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But there is a problem, the problem is that when you will have a look on the series of cities, many rows have same city names written in different way such as "Jammu and Kashmir" and "Jammu & Kashmir" or "delhi", "new delhi", "delhi new:new delhi" and "delhi/new delhi" or "Tamil Nadu", "Tamil nadu", TAMIL NADU" and "TAMILNADU", and in such cases all of these strings will be considered as different cities but they are same. Some similar case is with the series of States. You can also have a look on them here:

# %%
0                Ahmedabad
1                  Bhabhar
2                Ahmedabad
3                    Surat
4                Ahmedabad
5                   Rajkot
6                   Rajkot
7                Bangalore
8                  Dharwad
9                Jalandhar
10                Ludhiana
11               Jalandhar
12                  Khanna
13               Jalandhar
14                Ludhiana
15               Jalandhar
16                Amritsar
17                    Moga
18               Jalandhar
19               Jalandhar
20               Jalandhar
21              Chandigarh
22                 Chennai
23                 Chennai
24                 CHENNAI
25                 Chennai
26                 Chennai
27                   Salem
28                 Chennai
29                 Chennai
              ...         
51                Pilibhit
52                  Bijnor
53                  Meerut
54               Allahabad
55                Bareilly
56                 Kolkata
57                    Pune
58                  Nagpur
59                  Mumbai
60                  Mumbai
61                 Navapur
62         Rohtak, Haryana
63                   Delhi
64               New Delhi
65         New Delhi/Delhi
66               New Delhi
67               New Delhi
68               New Delhi
69                 GURGAON
70    Delhi New: New Delhi
71                   Delhi
72                   DELHI
73               New Delhi
74                   Delhi
75              SAMASTIPUR
76                   Patna
77      Thiruvananthapuram
78                  Kerala
79                   Kochi
80                   Kochi
Name: City, Length: 81, dtype: object

# %% [markdown]
# So, you have to first correct these typos so that the frequencies of different cities and states are evaluated properly and then plot the bar plots to get plots given as above.

# %% [markdown]
# The last task is to count the number of email addresses belonging to:
#
# gmail.com
#
# yahoo.com
#
# yahoo.co.in
